# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-QRLS7K3uNaqB_dqJxCdKGVqF511EVTi' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-QRLS7K3uNaqB_dqJxCdKGVqF511EVTi" -O imagewoof-320.zip && rm -rf /tmp/cookies.txt
# Out:
# --2021-04-23 16:04:46--  https://docs.google.com/uc?export=download&confirm=vw3i&id=1-QRLS7K3uNaqB_dqJxCdKGVqF511EVTi
# Resolving docs.google.com (docs.google.com)... 74.125.142.101, 74.125.142.100, 74.125.142.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-6o-docs.googleusercontent.com/docs/securesc/8roi7r0turnrrvh14k3l7jtvbf4ci1gv/pjkmhqpgl7r7iccf9jg38hfjm2uguo0e/1619193825000/16588752409781437759/01824612016195589896Z/1-QRLS7K3uNaqB_dqJxCdKGVqF511EVTi?e=download [following]
# --2021-04-23 16:04:46--  https://doc-08-6o-docs.googleusercontent.com/docs/securesc/8roi7r0turnrrvh14k3l7jtvbf4ci1gv/pjkmhqpgl7r7iccf9jg38hfjm2uguo0e/1619193825000/16588752409781437759/01824612016195589896Z/1-QRLS7K3uNaqB_dqJxCdKGVqF511EVTi?e=download
# ...

# %%
# !pip install efficientnet_pytorch
# Out:
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=a7e9f621a860d5e2e25056e153f74c7ec16d3672fc1754101aa735a3f3a51df9
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# ...

# %%
# !git clone https://github.com/core-matter/classification_pipeline
# Out:
# Cloning into 'classification_pipeline'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 73 (delta 40), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (73/73), done.

# %%
# !unzip -q /content/imagewoof-320.zip -d /content/classification_pipeline

# %%
cd classification_pipeline/
# Out:
# /content/classification_pipeline

# %%
# !mkdir checkpoints

# %%
# !python train.py -h
# Out:
# usage: train.py [-h] [--dataset_path DATASET_PATH]
#                 [--checkpoints_path CHECKPOINTS_PATH]
#                 [--writer_path WRITER_PATH] [--lr LR] [--epochs EPOCHS]
#                 [--warm_up_epochs WARM_UP_EPOCHS] [--num_classes NUM_CLASSES]
#                 [--batch_size BATCH_SIZE] [--start_epoch START_EPOCH]
#                 [--supervised_ratio SUPERVISED_RATIO]
#                 [--num_workers NUM_WORKERS] [--device DEVICE]
#                 [--model_name MODEL_NAME] [--pretrained PRETRAINED]
#                 [--experiment_name EXPERIMENT_NAME] [--resume_training]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --dataset_path DATASET_PATH
#   --checkpoints_path CHECKPOINTS_PATH
#   --writer_path WRITER_PATH
#                         path to save tensorboard logs
#   --lr LR               learning rate
#   --epochs EPOCHS       total number of epochs
#   --warm_up_epochs WARM_UP_EPOCHS
#   --num_classes NUM_CLASSES
# ...

# %%
# !python train.py --dataset_path /content/classification_pipeline/imagewoof2-320 --device cuda \
--epochs 25 --batch_size 32 --experiment_name effnet-b0 --warm_up_epochs 5
# Out:
# 2021-04-23 13:50:37.735742: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#   0% 0/25 [00:00<?, ?it/s]
#
# it: 20 lr: 4.2402826855123675e-05 train_loss:2.306117022037506 train_acc:0.1125
# it: 40 lr: 8.480565371024735e-05 train_loss:2.306996166706085 train_acc:0.11328125
# it: 60 lr: 0.00012720848056537105 train_loss:2.3034355958302815 train_acc:0.10989583333333333
# it: 80 lr: 0.0001696113074204947 train_loss:2.305064779520035 train_acc:0.112109375
# it: 100 lr: 0.00021201413427561838 train_loss:2.3113928842544555 train_acc:0.1115625
# it: 120 lr: 0.0002544169611307421 train_loss:2.313668737808863 train_acc:0.11354166666666667
# it: 140 lr: 0.0002968197879858657 train_loss:2.3114300421306067 train_acc:0.11629464285714286
# it: 160 lr: 0.0003392226148409894 train_loss:2.3096234798431396 train_acc:0.119140625
# it: 180 lr: 0.00038162544169611303 train_loss:2.3068748527103002 train_acc:0.12100694444444444
# ...

# %%
# !pip install tensorboard

# %%
# !tensorboard dev upload --logdir /content/classification_pipeline/logs/effnet-b0
# Out:
# 2021-04-23 15:04:21.676691: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# /content/classification_pipeline/logs/effnet-b0
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Continue? (yes/NO) yes
#
# ...

# %%
# !python predict.py -h
# Out:
# usage: predict.py [-h] [--dataset_path DATASET_PATH]
#                   [--result_path RESULT_PATH]
#                   [--checkpoints_path CHECKPOINTS_PATH] [--device DEVICE]
#                   [--model_name MODEL_NAME] [--image_path IMAGE_PATH]
#                   [--pretrained] [--num_classes NUM_CLASSES]
#                   [--experiment_name EXPERIMENT_NAME] [--one_sample]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --dataset_path DATASET_PATH
#   --result_path RESULT_PATH
#   --checkpoints_path CHECKPOINTS_PATH
#   --device DEVICE
#   --model_name MODEL_NAME
#   --image_path IMAGE_PATH
#   --pretrained
#   --num_classes NUM_CLASSES
#   --experiment_name EXPERIMENT_NAME
#   --one_sample

# %%
# !mkdir results

# %%
# !python predict.py --checkpoints_path checkpoints/  --experiment_name effnet-b0 \
--dataset_path /content/classification_pipeline/imagewoof2-320
# Out:
# 100% 3929/3929 [12:44<00:00,  5.14it/s]

# %%
import pandas as pd
result = pd.read_csv('results/effnet-b0.csv', index_col=None)
result
# Out:
#                                                img_name       true       pred
# 0     /content/classification_pipeline/imagewoof2-32...  n02111889  n02111889
# 1     /content/classification_pipeline/imagewoof2-32...  n02111889  n02111889
# 2     /content/classification_pipeline/imagewoof2-32...  n02111889  n02111889
# 3     /content/classification_pipeline/imagewoof2-32...  n02111889  n02111889
# 4     /content/classification_pipeline/imagewoof2-32...  n02111889  n02111889
# ...                                                 ...        ...        ...
# 3924  /content/classification_pipeline/imagewoof2-32...  n02087394  n02087394
# 3925  /content/classification_pipeline/imagewoof2-32...  n02087394  n02087394
# 3926  /content/classification_pipeline/imagewoof2-32...  n02087394  n02115641
# 3927  /content/classification_pipeline/imagewoof2-32...  n02087394  n02087394
# 3928  /content/classification_pipeline/imagewoof2-32...  n02087394  n02087394
#
# [3929 rows x 3 columns]
